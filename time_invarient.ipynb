# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
b=[2,-3,4]
a=[1]

# %%
n=np.arange(0,11)
x=np.sin(0.1*np.pi*n)
y=np.convolve(b,x,mode='full')

# %%
y=np.convolve(b,x,mode='full')

# %%
k=3
x_delayed=np.concatenate((np.zeros(k),x[:-k]))
y_delayed=np.concatenate((np.zeros(k),x[:-k]))

# %%
plt.subplot(2,1,1)
plt.stem(n,x)
plt.title('original input signal')
# Out:
# Text(0.5, 1.0, 'original input signal')

# %%
plt.subplot(2,1,2)
plt.stem(n,x_delayed)
plt.title(f'delayed output signal(k={k})')
# Out:
# Text(0.5, 1.0, 'delayed output signal(k=3)')

# %%
plt.subplot(2,1,2)
plt.stem(n,y_delayed)
plt.title(f'delayed output signal(k={k})')
# Out:
# Text(0.5, 1.0, 'delayed output signal(k=3)')

# %%
plt.subplot(2,1,2)
plt.stem(n,y)
plt.title(f'delayed output signal(k={k})')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 2
#       1 plt.subplot(2,1,2)
# ----> 2 plt.stem(n,y)
#       3 plt.title(f'delayed output signal(k={k})')
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:3832, in stem(linefmt, markerfmt, basefmt, bottom, label, orientation, data, *args)
#    3821 @_copy_docstring_and_deprecators(Axes.stem)
#    3822 def stem(
#    3823     *args: ArrayLike | str,
#    (...)
#    3830     data=None,
#    3831 ) -> StemContainer:
# -> 3832     return gca().stem(
#    3833         *args,
#    3834         linefmt=linefmt,
#    3835         markerfmt=markerfmt,
#    3836         basefmt=basefmt,
#    3837         bottom=bottom,
#    3838         label=label,
#    3839         orientation=orientation,
#    3840         **({"data": data} if data is not None else {}),
#    3841     )
#
# ...

# %%
plt.tight_layout()
plt.show()
